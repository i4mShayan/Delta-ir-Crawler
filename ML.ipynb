# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_parquet('data.parquet').to_csv('data.csv', index=False)

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#              id  region           town    city  price  price_per_meter  area  \
# 0  XQzQ28z_uyY=       2    saadat-abad  tehran  13000              162    80
# 1  0LsmLp41fQ4=       2    saadat-abad  tehran  12700              239    53
# 2  pog_EfrK~0I=       2    saadat-abad  tehran  32000              228   140
# 3  gkpuBV3VY5Q=       2    saadat-abad  tehran  18000              200    90
# 4  EbPIgX~uffI=       2  shahrak-gharb  tehran  16800              160   105
#
#    room_count  oldness  floor_count  has_parking  has_storeroom  has_elevator  \
# 0           1        5            3         True           True          True
# 1           1        8            5         True           True          True
# 2           2       12            2         True          False          True
# 3           2        9            3         True           True          True
# 4           2        8            1         True           True          True
#
# ...

# %%
x = data['region']
y = data['price']

# %%
plt.scatter(x, y, marker='x', c='r') 

# Set the title
plt.title("Profits vs. Population per city")
# Set the y-axis label
plt.ylabel('Profit in $10,000')
# Set the x-axis label
plt.xlabel('Population of City in 10,000s')
plt.show()

# %%
def show_3d_plot_of(x_label, y_lable, z_label, ):
    # Extract the columns
    x = data[x_label]
    y = data[y_lable]
    z = data[z_label]

    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the data
    ax.scatter(x, y, z)

    # Customize the plot
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_lable)
    ax.set_zlabel(z_label)

    ax.set_xlim([xmin, xmax])  # Set the minimum and maximum values for the X-axis
    ax.set_ylim([ymin, ymax])  # Set the minimum and maximum values for the Y-axis
    ax.set_zlim([zmin, zmax])  # Set the minimum and maximum values for the Z-axis
    # Show the plot
    plt.show()

# %%
x_label, y_lable, z_label = 'region', 'floor_count', 'price'
show_3d_plot_of(x_label, y_lable, z_label)

# %%
x_label, y_lable, z_label = 'region', 'floor_count', 'price_per_meter'
show_3d_plot_of(x_label, y_lable, z_label)

# %%
x_label, y_lable, z_label = 'region', 'oldness', 'price'
show_3d_plot_of(x_label, y_lable, z_label)

# %%
x_label, y_lable, z_label = 'region', 'oldness', 'price_per_meter'
show_3d_plot_of(x_label, y_lable, z_label)

# %%
x_label, y_lable, z_label = 'region', 'area', 'price'
show_3d_plot_of(x_label, y_lable, z_label)

# %%
x_label, y_lable, z_label = 'region', 'area', 'price_per_meter'
show_3d_plot_of(x_label, y_lable, z_label)

# %%
x_label, y_lable, z_label = 'oldness', 'floor_count', 'price_per_meter'
show_3d_plot_of(x_label, y_lable, z_label)
